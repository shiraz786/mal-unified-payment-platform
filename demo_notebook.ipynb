# %% [markdown]
# # Mal Unified Payment Pipeline Demo
# Run this notebook in Google Colab or Jupyter to demo the assessment quickly.

# %%
# !pip install -r requirements.txt

# %%
# !python src/pipeline.py

# %%
import json, pandas as pd
print(open('output/run_summary.json').read())
df = pd.read_parquet('output/unified_payments.parquet')
df.head()
